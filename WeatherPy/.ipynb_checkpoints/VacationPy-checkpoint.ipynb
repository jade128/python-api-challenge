# %%
# Dependencies
import requests
import json
import gmaps
import pandas as pd
import numpy as np
from config import gkey
from pprint import pprint

# %%
# read csv file
file="retrieved_city_data.csv"
cities_data_df=pd.read_csv(file)
city_df=(cities_data_df.drop(['Unnamed: 0','Lng','Lat'],axis=1)).dropna()

city_df.head()
# Out:
#               City Country  Temperature (F)  Humidity (%)  Cloudiness (%)  \
# 0         thompson      ca           -20.20          75.0             5.0
# 2           muisne      ec            76.48          92.0            66.0
# 3   saint-philippe      re            81.93          62.0            35.0
# 5  arraial do cabo      br            75.76          85.0             0.0
# 6           albany      au            73.40          56.0            20.0
#
#    Wind Speed (m/s)  Wind Speed (mph)
# 0              0.74          1.655336
# 2              1.97          4.406772
# 3              3.36          7.516118
# 5             10.80         24.158952
# 6             12.75         28.520985

# %%
#get lat lng for cities
city_df['Lat']=""
city_df["Lng"]=""

# use iterrows to iterate through pandas dataframe
for index, row in cities_data_df.iterrows():
    
    target_city=row["City"]
    region=row["Country"]
    
    # target url
    target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
    'address={0}&region={1}&key={2}').format(target_city,region, gkey)
    geo_data = requests.get(target_url).json()
    results = geo_data['results']
    # Extract latitude and longitude
    try:
       
        city_df.loc[index, 'Lat']= results[0]["geometry"]["location"]["lat"]
        city_df.loc[index, 'Lng']= results[0]["geometry"]["location"]["lng"]
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Out:
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.

# %%
city_df.head(200)



city_df.dtypes
# Out:
# City                 object
# Country              object
# Temperature (F)     float64
# Humidity (%)        float64
# Cloudiness (%)      float64
# Wind Speed (m/s)    float64
# Wind Speed (mph)    float64
# Lat                  object
# Lng                  object
# dtype: object

# %%
gmaps.configure(api_key=gkey)


# Convert humidity to float and store and  handle NaN values

# Store 'Lat' and 'Lng' into  locations 
city_df["Lat"] = pd.to_numeric(city_df["Lat"] , errors='coerce')
city_df["Lng"] = pd.to_numeric(city_df["Lng"] , errors='coerce')
city_df = city_df.dropna()
locations=city_df[["Lat","Lng"]]
humidity = city_df["Humidity (%)"].astype(float)

# %%
# Create a humidity Heatmap layer
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 3)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#define a ideal location for vacation
ideal_df= city_df.loc[( city_df["Temperature (F)"] <70.0) & (city_df["Temperature (F)"]>50.0) ]

ideal_df=ideal_df.loc[(ideal_df["Wind Speed (mph)"]<20) & (ideal_df["Cloudiness (%)"]<5) ]


# Convert humidity to float and store
# handle NaN values
ideal_df = ideal_df.dropna()
# Store 'Lat' and 'Lng' into  locations 
ideal_locations = ideal_df[["Lat", "Lng"]].astype(float)
ideal_humidity = ideal_df["Humidity (%)"].astype(float)
ideal_df.head()

ideal_df['name'] = ""
ideal_df['address'] = ""
ideal_df.head()
# Out:
#             City Country  Temperature (F)  Humidity (%)  Cloudiness (%)  \
# 37         sabha      ly            50.74          24.0             0.0
# 95    georgetown      us            63.34         100.0             1.0
# 194  henties bay      na            65.32          83.0             0.0
# 220       laguna      br            64.42          82.0             0.0
# 265          qom      ir            55.78          19.0             0.0
#
#      Wind Speed (m/s)  Wind Speed (mph)        Lat        Lng name address
# 37               3.18          7.113469  27.036541  14.429024
# 95               5.82         13.018991  38.907609 -77.072258
# 194              2.01          4.496249 -22.113496  14.283204
# 220              2.26          5.055484 -28.487606 -48.839740
# 265              1.59          3.556735  34.641576  50.874603

# %%
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(ideal_locations, weights=ideal_humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 3)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# find the closest hotel of each type to coordinates


target_radius = 5000
target_type = "lodging"
# set up a parameters dictionary
params = {
    
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# %%
# use iterrows to iterate through pandas dataframe
for index, row in  ideal_df.iterrows():

    # add keyword to params dict
    params['location'] =f"{row['Lat']},{row['Lng']}"

    # assemble url and make API request
    #print(f" Retrieving lodging for Index {index} : {row['Lat']}, {row['Lng']}.")
    response = requests.get(base_url, params=params).json()
    print(json.dumps(response, indent=4, sort_keys=True))
    # extract results
    results = response['results']
    
    try:
        print(f"first {row['Lat']},{row['Lng']} Hotal is {results[0]['name']}.")
        
        ideal_df.loc[index, 'name'] = results[0]['name']
        ideal_df.loc[index, 'address'] = results[0]['vicinity']

        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CqQCHAEAADxVzdKJq0tiahMO6NI7ib2YEFjFLzGDK4vxQqnqDe3raLpqmV_H1UvMi2QQuOcQcgzz7hIRs4HrgNONiuCInBod5x-TxW4DYrxjJDds0y3dM4JDCWdQvdrQi0iohAOMAMpc2IIGPrTB92B5nSyC7-eispBFMCi9oTNpSDxXRLfljTYAdhTusNhDneA3hO8Rlbi-G6hh6_ny-Tej3QiWdIqtBU3rsBPTegchkln5RhsoZrqT7Vajd8326Y9M6SAWLckuZDm9-UHWOAHpXrw0x-jmq8l5XGLa8fWrlFljEzBzorcIAuaZohC_nXwB_DzBoov-rZ5Jd7sZLTuamQbF00USLxCcO43CH-Bv-Nw6jwZBDLa7w70fEd7opE8D6ia_vhIQk2xfcie3RRgJRoTMoSEZ8BoUUDUHsJMbjwgHr1ioMicQvuHYdsg",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 27.0368274,
#                     "lng": 14.4301373
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 27.0381662802915,
#                         "lng": 14.4314716802915
#                     },
#                     "southwest": {
#                         "lat": 27.0354683197085,
#                         "lng": 14.4287737197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "f117e525d699cbe2922d60e1ddafdefb05bd989b",
#             "name": "\u0645\u062d\u0637\u0629 \u062a\u0627\u0643\u0633\u064a\u0627\u062a \u0627\u0644\u0634\u0627\u0637\u0626 \u0628\u0631\u0627\u0643",
#             "place_id": "ChIJtXIIN-r7xhMRKBDOmJOGZ18",
#             "plus_code": {
#                 "compound_code": "2CPJ+P3 Sabh\u0101, Libya",
#                 "global_code": "7FVP2CPJ+P3"
#             },
#             "rating": 4,
#             "reference": "ChIJtXIIN-r7xhMRKBDOmJOGZ18",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "\u0645\u062d\u0637\u0629 \u0633\u0628\u0647\u0627\u060c \u0633\u0628\u0647\u0627\u060c"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 27.0348833,
#                     "lng": 14.4291449
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 27.0360691302915,
#                         "lng": 14.4306707802915
#                     },
#                     "southwest": {
#                         "lat": 27.0333711697085,
#                         "lng": 14.4279728197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "21e27466838171290dc8aedfb74f53bc1b9a56de",
#             "name": "\u0645\u0633\u062c\u062f \u0627\u0639\u0628\u064a\u062f\u0629 \u0628\u0646 \u062c\u0631\u0627\u062d",
#             "place_id": "ChIJQWDkVkL7xhMR_63OnRww_8M",
#             "plus_code": {
#                 "compound_code": "2CMH+XM Sabh\u0101, Libya",
#                 "global_code": "7FVP2CMH+XM"
#             },
#             "reference": "ChIJQWDkVkL7xhMR_63OnRww_8M",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "\u0639\u0645\u0627\u0631\u0627\u062a \u0627\u0644\u0636\u0645\u0627\u0646"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 27.0380467,
#                     "lng": 14.4278714
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 27.0394197302915,
#                         "lng": 14.4291975802915
#                     },
#                     "southwest": {
#                         "lat": 27.0367217697085,
#                         "lng": 14.4264996197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "8011cd4cd9dff3eb97787e2df531db7f80d705a9",
#             "name": "\u0645\u062d\u0637\u0629 \u0627\u0645 \u0627\u0644\u0627\u0631\u0627\u0646\u0628 -\u0633\u0628\u0647\u0627 \u0645\u0648\u0627\u0635\u0644\u0627\u062a",
#             "place_id": "ChIJ_1dyIAH7xhMR5aAccu55ZOw",
#             "plus_code": {
#                 "compound_code": "2CQH+64 Sabh\u0101, Libya",
#                 "global_code": "7FVP2CQH+64"
#             },
#             "reference": "ChIJ_1dyIAH7xhMR5aAccu55ZOw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Sabh\u0101"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 27.0384905,
#                     "lng": 14.4270588
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 27.0398491302915,
#                         "lng": 14.4284201802915
#                     },
#                     "southwest": {
#                         "lat": 27.0371511697085,
#                         "lng": 14.4257222197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "d68f9dc7eedf93b4c384ebc46764edca1bf61b21",
#             "name": "\u0645\u062d\u0637\u0629 \u0633\u0641\u0631 \u0627\u0648\u0628\u0627\u0631\u064a",
#             "place_id": "ChIJCbQVAyb7xhMR-wGmK0OrNp0",
#             "plus_code": {
#                 "compound_code": "2CQG+9R Sabh\u0101, Libya",
#                 "global_code": "7FVP2CQG+9R"
#             },
#             "rating": 2,
#             "reference": "ChIJCbQVAyb7xhMR-wGmK0OrNp0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "\u0634\u0627\u0631\u0639 \u062c\u0645\u0627\u0644 \u0639\u0628\u062f \u0627\u0644\u0646\u0627\u0635\u0631\u060c \u0633\u0628\u0647\u0627\u060c"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 27.0328795,
#                     "lng": 14.4296127
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 27.0341458302915,
#                         "lng": 14.4309730802915
#                     },
#                     "southwest": {
#                         "lat": 27.0314478697085,
#                         "lng": 14.4282751197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "ad014dfba3354f20556a806757661f41720dc08a",
#             "name": "\u0645\u062c\u0648\u0647\u0631\u0627\u062a \u0646\u0631\u062c\u0633",
#             "place_id": "ChIJmYTBXmj7xhMRtXmHirnsgKQ",
#             "plus_code": {
#                 "compound_code": "2CMH+5R Sabh\u0101, Libya",
#                 "global_code": "7FVP2CMH+5R"
#             },
#             "reference": "ChIJmYTBXmj7xhMRtXmHirnsgKQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Sabh\u0101"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 27.0326197,
#                     "lng": 14.4299945
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 27.0339542302915,
#                         "lng": 14.4313689802915
#                     },
#                     "southwest": {
#                         "lat": 27.0312562697085,
#                         "lng": 14.4286710197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "d8c2231362c34bda650e990561383013db151777",
#             "name": "\u0633\u0627\u062c\u062f\u0647 \u0627\u0644\u0644\u0645\u0644\u0627\u0628\u0633 \u0627\u0644\u0646\u0633\u0627\u0626\u064a\u0647",
#             "place_id": "ChIJCfOACv37xhMRaqTGcfhnEQM",
#             "plus_code": {
#                 "compound_code": "2CMH+2X Sabh\u0101, Libya",
#                 "global_code": "7FVP2CMH+2X"
#             },
#             "reference": "ChIJCfOACv37xhMRaqTGcfhnEQM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Sabh\u0101"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 27.0324235,
#                     "lng": 14.4318005
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 27.0338056802915,
#                         "lng": 14.4331991302915
#                     },
#                     "southwest": {
#                         "lat": 27.0311077197085,
#                         "lng": 14.4305011697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "98a4539001ad6b5a04aef870a497cb85220f578d",
#             "name": "\u0627\u0644\u0648\u0627\u062d\u0629 \u0644\u0644\u0636\u064a\u0627\u0641\u0629 - Alwaha Guest House",
#             "place_id": "ChIJdfPK7wX7xhMRpROWyVXG7bg",
#             "plus_code": {
#                 "compound_code": "2CJJ+XP Sabh\u0101, Libya",
#                 "global_code": "7FVP2CJJ+XP"
#             },
#             "rating": 5,
#             "reference": "ChIJdfPK7wX7xhMRpROWyVXG7bg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "\u0627\u0644\u0642\u0631\u0636\u0629\u060c, Sabh\u0101"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 27.0316827,
#                     "lng": 14.433651
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 27.03307433029151,
#                         "lng": 14.4349711802915
#                     },
#                     "southwest": {
#                         "lat": 27.0303763697085,
#                         "lng": 14.4322732197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "555e72e05194c816e318d27c0d5cd1b52b6ea99b",
#             "name": "\u0641\u0646\u062f\u0642 \u0627\u0644\u0642\u0644\u0639\u0629 \u0633\u0628\u0647\u0627",
#             "place_id": "ChIJ03npbOr7xhMRhGASCrHJBzQ",
#             "plus_code": {
#                 "compound_code": "2CJM+MF Sabh\u0101, Libya",
#                 "global_code": "7FVP2CJM+MF"
#             },
#             "rating": 2,
#             "reference": "ChIJ03npbOr7xhMRhGASCrHJBzQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Unnamed Road\u060c\u060c"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 27.0316803,
#                     "lng": 14.4336507
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 27.0330727802915,
#                         "lng": 14.4349703302915
#                     },
#                     "southwest": {
#                         "lat": 27.0303748197085,
#                         "lng": 14.4322723697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "c3a3fcc0a760fbbe562d1cc9fc132e9b7bbd11b7",
#             "name": "\u0639\u0645\u0627\u0631\u0627\u062a \u0627\u0644\u0636\u0645\u0627\u0646 \u0627\u0644\u0627\u062c\u062a\u0645\u0627\u0639\u064a _ \u0627\u0644\u0642\u0631\u0636\u0629",
#             "place_id": "ChIJlcI8yxD7xhMRX23cfeDpFSU",
#             "plus_code": {
#                 "compound_code": "2CJM+MF Sabh\u0101, Libya",
#                 "global_code": "7FVP2CJM+MF"
#             },
#             "reference": "ChIJlcI8yxD7xhMRX23cfeDpFSU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Unnamed Road\u060c"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 27.0303839,
#                     "lng": 14.4309527
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 27.0317216302915,
#                         "lng": 14.4323024802915
#                     },
#                     "southwest": {
#                         "lat": 27.0290236697085,
#                         "lng": 14.4296045197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "8ca23cc8f4099ca70a19c08552d818d1e85a0555",
#             "name": "\u0645\u062d\u0637\u0629 \u0633\u0641\u0631 \u063a\u0627\u062a",
#             "place_id": "ChIJSavb0ST7xhMRLZPHJe5KUUI",
#             "plus_code": {
#                 "compound_code": "2CJJ+59 Sabh\u0101, Libya",
#                 "global_code": "7FVP2CJJ+59"
#             },
#             "reference": "ChIJSavb0ST7xhMRLZPHJe5KUUI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Unnamed Road, \u0633\u0628\u0647\u0627\u060c"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 27.0338435,
#                     "lng": 14.4365314
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 27.0351005802915,
#                         "lng": 14.4377625302915
#                     },
#                     "southwest": {
#                         "lat": 27.0324026197085,
#                         "lng": 14.4350645697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "7ee67b1a2c651861865f9845f34baff9b77b29a4",
#             "name": "Girl's hostel - Sebha University",
#             "place_id": "ChIJjUrdugL7xhMRqeLWAS7bP0I",
#             "plus_code": {
#                 "compound_code": "2CMP+GJ Sabh\u0101, Libya",
#                 "global_code": "7FVP2CMP+GJ"
#             },
#             "rating": 2.3,
#             "reference": "ChIJjUrdugL7xhMRqeLWAS7bP0I",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 4,
#             "vicinity": "Sabh\u0101"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 27.0284718,
#                     "lng": 14.4280995
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 27.02978313029151,
#                         "lng": 14.4295900302915
#                     },
#                     "southwest": {
#                         "lat": 27.0270851697085,
#                         "lng": 14.4268920697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "496d11c2545325bcfe7ad4b37c6b879268065eb4",
#             "name": "\u0645\u0646\u062a\u0632\u0647 \u0627\u0644\u0646\u062e\u0644\u0629 \u0627\u0644\u0645\u0636\u064a\u0626\u0629",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "place_id": "ChIJqx6F3Bn7xhMR1QYdPdYFtC4",
#             "plus_code": {
#                 "compound_code": "2CHH+96 Sabh\u0101, Libya",
#                 "global_code": "7FVP2CHH+96"
#             },
#             "rating": 4.2,
#             "reference": "ChIJqx6F3Bn7xhMR1QYdPdYFtC4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 5,
#             "vicinity": "\u0627\u0644\u0642\u0631\u0636\u0629\u060c, Sabh\u0101"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 27.03637519999999,
#                     "lng": 14.4399491
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 27.0376929302915,
#                         "lng": 14.4411536302915
#                     },
#                     "southwest": {
#                         "lat": 27.0349949697085,
#                         "lng": 14.4384556697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "13210818f7df16913494e4d4d6919e7329e68bfb",
#             "name": "Residential apartments of Sebha University",
#             "place_id": "ChIJi2o19xz7xhMRy7ZBWGBZUJQ",
#             "plus_code": {
#                 "compound_code": "2CPQ+HX Sabh\u0101, Libya",
#                 "global_code": "7FVP2CPQ+HX"
#             },
#             "reference": "ChIJi2o19xz7xhMRy7ZBWGBZUJQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Sabh\u0101"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 27.0449007,
#                     "lng": 14.421161
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 27.04622618029149,
#                         "lng": 14.4224781302915
#                     },
#                     "southwest": {
#                         "lat": 27.04352821970849,
#                         "lng": 14.4197801697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "306b569eb2f8e8d3ec2fcfab502178c30b9c047b",
#             "name": "\u0645\u0639\u0631\u0636 \u0627\u0644\u0646\u062c\u0645 \u0627\u0644\u0630\u0647\u0628\u064a \u0644\u0644\u0633\u062c\u0627\u062f",
#             "place_id": "ChIJ_T6JQ3_7xhMRgKypPMq8F0M",
#             "plus_code": {
#                 "compound_code": "2CVC+XF Sabh\u0101, Libya",
#                 "global_code": "7FVP2CVC+XF"
#             },
#             "reference": "ChIJ_T6JQ3_7xhMRgKypPMq8F0M",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "\u0634\u0627\u0631\u0639 \u062c\u0645\u0627\u0644 \u0639\u0628\u062f \u0627\u0644\u0646\u0627\u0635\u0631\u060c, Sabh\u0101"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 27.028195,
#                     "lng": 14.4379278
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 27.0295916802915,
#                         "lng": 14.4392166802915
#                     },
#                     "southwest": {
#                         "lat": 27.0268937197085,
#                         "lng": 14.4365187197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "46d8594b494da09fde35affab6866dd477f0a1f4",
#             "name": "\u0641\u0646\u062f\u0642 \u0623\u0641\u0631\u064a\u0642\u064a\u0627",
#             "place_id": "ChIJj4nf8ib7xhMRccNDXycq94E",
#             "plus_code": {
#                 "compound_code": "2CHQ+75 Sabh\u0101, Libya",
#                 "global_code": "7FVP2CHQ+75"
#             },
#             "rating": 5,
#             "reference": "ChIJj4nf8ib7xhMRccNDXycq94E",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "\u0627\u0644\u0642\u0631\u0636\u0629\u060c\u060c"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 27.025096,
#                     "lng": 14.41666
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 27.0265311802915,
#                         "lng": 14.4178464302915
#                     },
#                     "southwest": {
#                         "lat": 27.0238332197085,
#                         "lng": 14.41514846970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "6a56493c0585083fb9a011f2ce047bf816f509dc",
#             "name": "\u0625\u062f\u0631\u064a\u0633 \u062c\u0628\u0631\u064a\u0644 \u0627\u0644\u063a\u0627\u0644\u064a",
#             "place_id": "ChIJyaUV7qP7xhMRRN7KkZtmD8M",
#             "plus_code": {
#                 "compound_code": "2CG8+2M Sabh\u0101, Libya",
#                 "global_code": "7FVP2CG8+2M"
#             },
#             "reference": "ChIJyaUV7qP7xhMRRN7KkZtmD8M",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "\u0633\u0628\u0647\u0627\u060c"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 27.0445716,
#                     "lng": 14.4101086
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 27.0459794802915,
#                         "lng": 14.4116164302915
#                     },
#                     "southwest": {
#                         "lat": 27.0432815197085,
#                         "lng": 14.4089184697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "3e86f4e278fb7f73cbda21c1a15ab054a69b5793",
#             "name": "\u0645\u062d\u0637\u0629 \u0645\u064a\u0627\u0647 \u0627\u0644\u062c\u062f\u064a\u062f \u0627\u0644\u0633\u0643\u0646\u064a\u0629",
#             "place_id": "ChIJcXyui8T7xhMRAa6828pto94",
#             "plus_code": {
#                 "compound_code": "2CV6+R2 Sabh\u0101, Libya",
#                 "global_code": "7FVP2CV6+R2"
#             },
#             "reference": "ChIJcXyui8T7xhMRAa6828pto94",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "\u0634\u0627\u0631\u0639 \u0639\u0645\u0631 \u0627\u0644\u0645\u062e\u062a\u0627\u0631\u060c \u0633\u0628\u0647\u0627\u060c"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 27.0495548,
#                     "lng": 14.4118678
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 27.0509200302915,
#                         "lng": 14.4131508802915
#                     },
#                     "southwest": {
#                         "lat": 27.0482220697085,
#                         "lng": 14.4104529197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "6f17f6e030ed86c62965e4c0c9a7a85bdaa6a649",
#             "name": "\u0641\u0646\u062f\u0642 \u0639\u0644\u064a",
#             "place_id": "ChIJq24Y5nf7xhMRltuD0AUJ88Q",
#             "plus_code": {
#                 "compound_code": "2CX6+RP Sabh\u0101, Libya",
#                 "global_code": "7FVP2CX6+RP"
#             },
#             "reference": "ChIJq24Y5nf7xhMRltuD0AUJ88Q",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "\u0627\u0644\u062c\u062f\u064a\u062f\u060c"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 27.0552236,
#                     "lng": 14.4155153
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 27.0566159302915,
#                         "lng": 14.4168711302915
#                     },
#                     "southwest": {
#                         "lat": 27.0539179697085,
#                         "lng": 14.4141731697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "71d2c966e03b28aa9b5ff0c962efbe223b900bbb",
#             "name": "\u0641\u0646\u062f\u0642 \u0627\u0644\u0628\u0631\u0643\u0648\u0644\u064a",
#             "place_id": "ChIJwforGUD7xhMRDtwG4LaxcQI",
#             "plus_code": {
#                 "compound_code": "3C48+36 Sabh\u0101, Libya",
#                 "global_code": "7FVP3C48+36"
#             },
#             "reference": "ChIJwforGUD7xhMRDtwG4LaxcQI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "\u0627\u0644\u062c\u062f\u064a\u062f \u0633\u0628\u0647\u0627\u060c"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 27.0599264,
#                     "lng": 14.4222471
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 27.0608906802915,
#                         "lng": 14.4233970802915
#                     },
#                     "southwest": {
#                         "lat": 27.0581927197085,
#                         "lng": 14.4206991197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "dcf3b1e1f5bc8b5507e2133697fd204267a35164",
#             "name": "\u0641\u0646\u062f\u0642 \u0627\u0644\u0645\u0648\u0627\u062c\u064a\u062f",
#             "place_id": "ChIJHQiOPTP7xhMRMwnksTgIreY",
#             "plus_code": {
#                 "compound_code": "3C5C+XV Sabh\u0101, Libya",
#                 "global_code": "7FVP3C5C+XV"
#             },
#             "reference": "ChIJHQiOPTP7xhMRMwnksTgIreY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "\u0645\u062e\u0627\u0632\u0646 \u0627\u0644\u0623\u0633\u0648\u0627\u0642 \u0633\u0627\u0628\u0642\u0627\u064b, \u0633\u0628\u0647\u0627-\u062d\u064a \u0639\u0628\u062f\u0627\u0644\u0643\u0627\u0641\u064a \u0645\u0642\u0627\u0628\u0644, Sabh\u0101"
#         }
#     ],
#     "status": "OK"
# }
# first 27.0365406,14.4290236 Hotal is محطة تاكسيات الشاطئ براك.
# ------------
# {
#     "html_attributions": [],
#     "next_page_token": "CqQCHAEAAORcXVcOT51lYdcWe3PUrj-TivFKj3EHmlS9LhvqNONngy6l4ytihnNAPpJxp3RdijB0SRiT4MDw5elgXQmZVl9xyD7jOmthLVOklov0vxzlGlU9lkqZNgADW_SACzf8Vx_68UCh5RmvHV9EY75-swKGPqlvmjn6H2YDWZbD-3uxo0PUV9pavlnVplEP4toADg1nT2t4G6NmqIqHBtdfqZz9eRJv_n9LPQ9MjzTCDCa3VjJk3wkFr43UVbTqjEgVfwXqiDeDpQ4hEGb_jzt0eL8_UVSGed44Kp1YJjFOp7LrQX_4L7HdZYT7jkEME2doEtTwK7KvSTDu-Ketw43d1x-uU752qbF12vlt-PP3_mG8aFhccIZNO043zXuFfbxS6BIQyf_UkO8BKdxCh9eJ-aEOEBoUF_Nh6JWt7JlA5N5L2S7jYTzeELY",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.89707360000001,
#                     "lng": -77.0224515
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.8984875302915,
#                         "lng": -77.0211008197085
#                     },
#                     "southwest": {
#                         "lat": 38.8957895697085,
#                         "lng": -77.02379878029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "889c2e1e51726d976eb6f0666551a8a264df57d8",
#             "name": "Kimpton Hotel Monaco Washington DC",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115387634265856395533\">Hakol B&#39;zman</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAmOUbYTaivy8rd--87HgfmoaKy2qldJh0n15KXEzw56-TFKqy1nIoxcmxgZrNrE3mIvndXGoFC-dfEsuWam_RvoNF0qGWlP6mHI8juVrsYinmm51yMKHrcISbKiuwYVO3EhD-hd43PKHXgXODRCRsDNkuGhQ28QNprbUTEN6sd9Gf3Tjc5SaCMg",
#                     "width": 5312
#                 }
#             ],
#             "place_id": "ChIJG8fi0pG3t4kR-Ilr8brNrJc",
#             "plus_code": {
#                 "compound_code": "VXWH+R2 Washington, District of Columbia, United States",
#                 "global_code": "87C4VXWH+R2"
#             },
#             "price_level": 3,
#             "rating": 4.4,
#             "reference": "ChIJG8fi0pG3t4kR-Ilr8brNrJc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 979,
#             "vicinity": "700 F Street Northwest, Washington"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.9071986,
#                     "lng": -77.06355359999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.9085893802915,
#                         "lng": -77.06206736970849
#                     },
#                     "southwest": {
#                         "lat": 38.9058914197085,
#                         "lng": -77.0647653302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "704318459be2f9cb2ded26228e7e9c8496863bd6",
#             "name": "The Georgetown Inn",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2933,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108360724959926209466\">Alex Tucker</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAT0q9BxqSZ_m9ohlWjkNDK-J1WIMT0DrZqIA4eeEF5hq8fq08srRis8O6ROeVDNLvqLE-gD9UsD7NHley2-GHauF6uz7zTd1DzH-0RV6ALJMPo7q91ZaOl-Xm9t4ylncZEhBo3Lfjg_HHSuW0v3fhLaBBGhR975aptMR71a10vxpg7ZkgHxWk3A",
#                     "width": 3911
#                 }
#             ],
#             "place_id": "ChIJETxQmUm2t4kR9dO7ZkjKbiU",
#             "plus_code": {
#                 "compound_code": "WW4P+VH Washington, District of Columbia, United States",
#                 "global_code": "87C4WW4P+VH"
#             },
#             "rating": 4.3,
#             "reference": "ChIJETxQmUm2t4kR9dO7ZkjKbiU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 337,
#             "vicinity": "1310 Wisconsin Avenue Northwest, Washington"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.8995288,
#                     "lng": -77.0732441
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.90101293029149,
#                         "lng": -77.07153911970849
#                     },
#                     "southwest": {
#                         "lat": 38.89831496970849,
#                         "lng": -77.0742370802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "483f7f5573ae637dc6b676fd5a6582063ac516c5",
#             "name": "Key Bridge Marriott",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3120,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104379985670892993138\">Ahmed Al-Amri</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAPu6ElkXZpuU-r7uhFH_X9u0jS27Z-fDystg9oz_uDvXhxhfKEPo9pWulrI79EzNS26hrq0UonyMQlSCElF9jBq5seWY__3TqX5Uyg0G27519VXlY8RpUzOVWrA8S90N4EhASEcA7cm5LedWOI4lmlVoxGhQrwE3u8v3uNgQP6xmT7IFvQjkmtw",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJo3xbW162t4kRp4UJOwRwxWg",
#             "plus_code": {
#                 "compound_code": "VWXG+RP Arlington, Mason, VA, United States",
#                 "global_code": "87C4VWXG+RP"
#             },
#             "rating": 3.9,
#             "reference": "ChIJo3xbW162t4kRp4UJOwRwxWg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1863,
#             "vicinity": "1401 Lee Highway, Arlington"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.9029838,
#                     "lng": -77.06173179999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.9045002302915,
#                         "lng": -77.06042181970848
#                     },
#                     "southwest": {
#                         "lat": 38.9018022697085,
#                         "lng": -77.06311978029149
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "20f05129383a4f592dae37fc46c03c529d9fea53",
#             "name": "The Ritz-Carlton Georgetown, Washington, D.C.",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1444,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104031322996786469533\">The Ritz-Carlton Georgetown, Washington, D.C.</a>"
#                     ],
#                     "photo_reference": "CmRZAAAA6UdjC173wd_Ubq9Dvm3_zegLRTHuvcZcsewz3bS5NP2g-9qNJV11l2fSLpV-PO_fIT-JNTsO8rN-TysI9R_w9ci7lI0nmALBojPq5f-N2wtUnvJVymBHgjk8Mc4COEKKEhA6Fd1DUXpvIP4gVawpGJDuGhQ9YnURnYhaTYOkaj_deY5Evq-FQg",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJwf9lG0y2t4kRND842TyP9FA",
#             "plus_code": {
#                 "compound_code": "WW3Q+58 Washington, District of Columbia, United States",
#                 "global_code": "87C4WW3Q+58"
#             },
#             "price_level": 4,
#             "rating": 4.7,
#             "reference": "ChIJwf9lG0y2t4kRND842TyP9FA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 347,
#             "vicinity": "3100 South Street Northwest, Washington"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.89772779999999,
#                     "lng": -77.0732401
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.89909738029149,
#                         "lng": -77.0715526197085
#                     },
#                     "southwest": {
#                         "lat": 38.89639941970849,
#                         "lng": -77.0742505802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "86a0c116cbf3baa632591fd2745b4de9e0b9058f",
#             "name": "Holiday Inn Rosslyn @ Key Bridge",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3225,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103240010276243341726\">Holiday Inn Rosslyn @ Key Bridge</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAXSo46Z4MZBz21K7QMaPguPxGOVnQrE_cB9u4qKRcEZ8WPzSmCFaAKrMsReTx23UyN5tQzcuJsOCYQf7T8fSFYXDWipC_I9F77VSMsekcGLwXQBr5cE3j7Up3zdcQzBJ6EhAV42d1JdaodSjDnhz2rMqCGhSjodCkBQrLtPad-KCMRXyufrGHhA",
#                     "width": 4378
#                 }
#             ],
#             "place_id": "ChIJHWpAnlu2t4kRz70nhMKp4V8",
#             "plus_code": {
#                 "compound_code": "VWXG+3P Arlington, Mason, VA, United States",
#                 "global_code": "87C4VWXG+3P"
#             },
#             "rating": 3.9,
#             "reference": "ChIJHWpAnlu2t4kRz70nhMKp4V8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1826,
#             "vicinity": "1900 Fort Myer Drive, Arlington"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.897275,
#                     "lng": -77.0700761
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.8985972802915,
#                         "lng": -77.06879596970849
#                     },
#                     "southwest": {
#                         "lat": 38.8958993197085,
#                         "lng": -77.0714939302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "723c7a0298dd5e2c7e25fc49fba40362372470bd",
#             "name": "Le M\u00e9ridien Arlington",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1365,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115812386326839258710\">Le M\u00e9ridien Arlington</a>"
#                     ],
#                     "photo_reference": "CmRaAAAATY-P7eyfQtr_riAsn_Wz2PBNoAOvj8KCrHWzCFWzWBUFTOxappSq4zi4e0l4as5LE1iY5Ka-5SVVgidhxBYEh_mKF4LOeE1AC-D9FzfoSIz6KvdBSd51C_cYXNXdI1PoEhDqLEZR5_AfcS2r7KtyNUUDGhQ4iaa3Pb8llVihkn2WAD4MeLdQtg",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJ8dPaV1q2t4kRKi7EnpFnv8c",
#             "plus_code": {
#                 "compound_code": "VWWH+WX Arlington, Mason, VA, United States",
#                 "global_code": "87C4VWWH+WX"
#             },
#             "rating": 4.1,
#             "reference": "ChIJ8dPaV1q2t4kRKi7EnpFnv8c",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 754,
#             "vicinity": "1121 19th Street North, Arlington"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.9044999,
#                     "lng": -77.05849
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.9058574302915,
#                         "lng": -77.05719661970849
#                     },
#                     "southwest": {
#                         "lat": 38.9031594697085,
#                         "lng": -77.05989458029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "fecf15753acb4ff8931f85242e624255820e6716",
#             "name": "Georgetown Suites",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3708,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112189878707503054468\">Georgetown Suites</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAbqJR3rQUlxnsp_RVQCtheP_1b7hK0R5YkUi0koExWn46ZdBzYn_PKmj3nbTT2Xk_HE9DZKUUJsgVcNIue3sdZjSxzD73vX6nm1w4Dq5T6Ap6SNV7_cslDea5T0n-Z3i6EhDAsuu51WGB8RJ4bSQDM2rfGhTeq8gEbRPwAUF8e_pDtWRuaw8jRA",
#                     "width": 5000
#                 }
#             ],
#             "place_id": "ChIJC7UrcEu2t4kRdqDQ5cw_uoQ",
#             "plus_code": {
#                 "compound_code": "WW3R+QJ Washington, District of Columbia, United States",
#                 "global_code": "87C4WW3R+QJ"
#             },
#             "rating": 4.3,
#             "reference": "ChIJC7UrcEu2t4kRdqDQ5cw_uoQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "real_estate_agency",
#                 "travel_agency",
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 580,
#             "vicinity": "1111 30th Street Northwest, Washington"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.90472219999999,
#                     "lng": -77.0572222
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.90608143029149,
#                         "lng": -77.0558745697085
#                     },
#                     "southwest": {
#                         "lat": 38.90338346970849,
#                         "lng": -77.05857253029151
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "3f647f875fb2321b30461d7361d9edd23c04ee11",
#             "name": "Four Seasons Hotel Washington, DC",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 720,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107917339510811683810\">Four Seasons Hotel Washington, DC</a>"
#                     ],
#                     "photo_reference": "CmRaAAAApjhlWXc6Zu3pvVeOceoyD-QKlB5qakNBMRO6vSyNNCp4n33iTZ3Xytob2Ntbrn2Dk8sA0IH5FFuTPpfNz8gPRpKqlAzrMDYRjqHRfZK0HcPXDeQANnv1PaR4MJvVf2TTEhAtpKpLMLr_2ROuCGEgnY7gGhSVYoLHXWhfcwwgJ-BF9VkIGodMJg",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJNdBhOEu2t4kR6zkWO2XCzFI",
#             "plus_code": {
#                 "compound_code": "WW3V+V4 Washington, District of Columbia, United States",
#                 "global_code": "87C4WW3V+V4"
#             },
#             "price_level": 4,
#             "rating": 4.7,
#             "reference": "ChIJNdBhOEu2t4kR6zkWO2XCzFI",
#             "scope": "GOOGLE",
#             "types": [
#                 "spa",
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1405,
#             "vicinity": "2800 Pennsylvania Avenue Northwest, Washington"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.89513779999999,
#                     "lng": -77.07278360000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.89648253029149,
#                         "lng": -77.07155091970849
#                     },
#                     "southwest": {
#                         "lat": 38.8937845697085,
#                         "lng": -77.0742488802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "d9d7a03ed2b797ec3e0be95d211e4d3cf5cf9704",
#             "name": "Hyatt Centric Arlington",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1920,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111484959728943956972\">Hyatt Centric Arlington</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAM6MA8pL9_7gbN7mMWqC9uZegSC0jNi4JPTfLk59uZv2l6N1aOgSnqf5N8uEQhFV95EuFCmCmY_QDdwa2UXxb5h59f3f4SpCwqo2caCBFwQmCENorioO9OXGKGG6e57gkEhBAW-6vnJHDvWycth99ym8eGhQKs-GrBX28EPN4VO4vR6mryR4eow",
#                     "width": 2880
#                 }
#             ],
#             "place_id": "ChIJ25FE_Vu2t4kRU-smhllnkxc",
#             "plus_code": {
#                 "compound_code": "VWWG+3V Arlington, Mason, VA, United States",
#                 "global_code": "87C4VWWG+3V"
#             },
#             "rating": 4.3,
#             "reference": "ChIJ25FE_Vu2t4kRU-smhllnkxc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1170,
#             "vicinity": "1325 Wilson Boulevard, Arlington"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.8937009,
#                     "lng": -77.0731935
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.8951052802915,
#                         "lng": -77.0719619697085
#                     },
#                     "southwest": {
#                         "lat": 38.8924073197085,
#                         "lng": -77.0746599302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "2965c3acb582090e6d9971ece06a6cc108b1d4ea",
#             "name": "Residence Inn by Marriott Arlington Rosslyn",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2048,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112303479840561744055\">Residence Inn by Marriott Arlington Rosslyn</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAT7UFymsuyGzOAE26h0mX3p-JXmtDsOvS9mlabPbHk5BSskbD9pydKHyLA8rXZ4qvutC8f2UVdWSGqMm7st-17nmU4TEawSAQczmAPzTnSAGTvOpozvJA-CJ98V9wxqNjEhAilkRb4j70NHsSDLxPUvtrGhQS5hGihLNOc7gL8-Nk4f_qWyjz9Q",
#                     "width": 1366
#                 }
#             ],
#             "place_id": "ChIJp4CYNVm2t4kRhkRHxIlJSTE",
#             "plus_code": {
#                 "compound_code": "VWVG+FP Arlington, Mason, VA, United States",
#                 "global_code": "87C4VWVG+FP"
#             },
#             "rating": 4.3,
# ...
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -42.7323219697085,
#                         "lng": 170.9949770302915
#                     },
#                     "southwest": {
#                         "lat": -42.7350199302915,
#                         "lng": 170.9922790697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "3d4f3e50c468c2a418caa61713bbe44f6f0908f0",
#             "name": "Riverview Cabins - BBH",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3120,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110820907450828838575\">Saou-Wen Su</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAXtWo9Hk4W-eEvQtJS_-8tLZiQeGjxFg2T1pla5ZzxEJfspDX34rbPrFEMzyEwL41OgCurO7KPr0hJ8upOXLHTVYDxLqNMLfzThKP9R-xL_k6o9PFS61APk47d-PnZevXEhBugHtTHtrCFZkpVXmP2-xfGhT4ID03FaC-SxC9DOGikezggpXCFw",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJkcdUEPolL20RtbEoz3jw82c",
#             "plus_code": {
#                 "compound_code": "7X8V+GC Kaniere, West Coast, New Zealand",
#                 "global_code": "4V9G7X8V+GC"
#             },
#             "rating": 4,
#             "reference": "ChIJkcdUEPolL20RtbEoz3jw82c",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 6,
#             "vicinity": "154 Kaniere Road, Kaniere"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -42.7462189,
#                     "lng": 170.9328776
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -42.7447926697085,
#                         "lng": 170.9341297802915
#                     },
#                     "southwest": {
#                         "lat": -42.74749063029149,
#                         "lng": 170.9314318197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "b6c1e735a4002b4e9d6a210e69f523e81f77fcaf",
#             "name": "West Coast SCENIC WATERWAYS retreat",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103843566553662899878\">West Coast SCENIC WATERWAYS retreat</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAhjNUo7hBibOmQwm-m0eKMY-blYSyE6lPVrOXEdDhhZYizE_3JkrY3fWSRXa-1BoufAuuAljiUt5BbuHH4kRdNqFRyBMBIG6dXECKNvZHseNapoIiL7rqWtcm248t3hBDEhCQz4z2ldMsfx1pLQzJCPKUGhSGTX-60gHfTiPyVzirUUzDxVGKSA",
#                     "width": 5312
#                 }
#             ],
#             "place_id": "ChIJheFXgSkpL20RoMMgsO1F6qA",
#             "plus_code": {
#                 "compound_code": "7W3M+G5 Hokitika, West Coast, New Zealand",
#                 "global_code": "4V9G7W3M+G5"
#             },
#             "rating": 4.9,
#             "reference": "ChIJheFXgSkpL20RoMMgsO1F6qA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 13,
#             "vicinity": "389 Ruatapu Road, Takutai Road, Hokitika"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -42.7182858,
#                     "lng": 170.9614225
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -42.7170020697085,
#                         "lng": 170.9627082302915
#                     },
#                     "southwest": {
#                         "lat": -42.7197000302915,
#                         "lng": 170.9600102697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "892e47609c4c418b9db325f6f7260e661a263cb1",
#             "name": "Teichelmanns Bed and Breakfast",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 960,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117080392550531719277\">Teichelmanns Bed and Breakfast</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAHgpF0rtkIfP7RrHANn0o42pBM7YtN7f93UhbNcIAfTWvPswzRnmMK_upu7KVzKfnvNYM8-WMuVx54AgmHPa7dc9LCesYjYTFATOkE_LjvNKqWdunNPS_LonDhnidq00GEhAi7BSgLr3mlRkGqgjnkFo-GhTNkTof6BxF9_XwVDUz5MarZGznHw",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJsV47TRQvL20RBkJ-oqqirKg",
#             "plus_code": {
#                 "compound_code": "7XJ6+MH Hokitika, West Coast, New Zealand",
#                 "global_code": "4V9G7XJ6+MH"
#             },
#             "rating": 5,
#             "reference": "ChIJsV47TRQvL20RBkJ-oqqirKg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 27,
#             "vicinity": "20 Hamilton Street, Hokitika"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -42.74933469999999,
#                     "lng": 170.9313055
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -42.7474552697085,
#                         "lng": 170.932129
#                     },
#                     "southwest": {
#                         "lat": -42.75015323029149,
#                         "lng": 170.928835
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "4cf2e9992b699c8a0eadb9967716caed4a276242",
#             "name": "Kotuku Cottage",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109778982243218463831\">Thane Terrill</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAp-nqCLhK4KA0uXYljPqpFODCDWtVLxDHki7APbswZjapciLZmB8mtj2S8uUWdC_Ltq5AV-yVxFhS5_uGaaa_Q2upgXZwA3_9oCH4j2SPYbFHsHR4qPeIfxl_-dFyBCtBEhA6yZ5Jwej_MovvdZdIm4noGhR7Gf5TcesZA4Nw6dYP55n2o2tZgg",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJ9x6ULHEpL20RRnJojgxjAcM",
#             "plus_code": {
#                 "compound_code": "7W2J+7G Ruatapu, West Coast, New Zealand",
#                 "global_code": "4V9G7W2J+7G"
#             },
#             "rating": 4.9,
#             "reference": "ChIJ9x6ULHEpL20RRnJojgxjAcM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 20,
#             "vicinity": "420 Ruatapu Road, Ruatapu"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -42.7319212,
#                     "lng": 170.9629321
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -42.7304574697085,
#                         "lng": 170.9643866302915
#                     },
#                     "southwest": {
#                         "lat": -42.7331554302915,
#                         "lng": 170.9616886697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "4caf0877af411993ff3ef63b95314d75275b8ea7",
#             "name": "Te Punga private room",
#             "place_id": "ChIJm7csvTcvL20R53KK743ErRI",
#             "plus_code": {
#                 "compound_code": "7X97+65 Ruatapu, West Coast, New Zealand",
#                 "global_code": "4V9G7X97+65"
#             },
#             "rating": 5,
#             "reference": "ChIJm7csvTcvL20R53KK743ErRI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "40 Arthurstown Road, Hokitika"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -42.718362,
#                     "lng": 170.9608951
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -42.7169614197085,
#                         "lng": 170.9622941802915
#                     },
#                     "southwest": {
#                         "lat": -42.7196593802915,
#                         "lng": 170.9595962197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "aa629cbabbd308d7f1255fd25df93948dd14b9e3",
#             "name": "Hokitika Fire Station Boutique Accommodation",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1365,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117121115023944682833\">Hokitika Fire Station Boutique Accommodation</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAte4r0XGyEq7cifTp1adERIoO9CfXNyJ-Uybqu2yc2oFEVWxcfz0GiAxMv9V4ru1bUqL1ekUln2xCvhQcMNeNkbd13g6zmkBXnj0jc3ewNOgeJ2KUn8zBHFm8ECIqCHykEhD_yiOkT27LQxopLdNgoeNGGhSkrU2bXK28El067VEQSry-e2yn9Q",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJGxMqSxQvL20RP9BCh3dppPc",
#             "plus_code": {
#                 "compound_code": "7XJ6+M9 Hokitika, West Coast, New Zealand",
#                 "global_code": "4V9G7XJ6+M9"
#             },
#             "rating": 5,
#             "reference": "ChIJGxMqSxQvL20RP9BCh3dppPc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 6,
#             "vicinity": "9 Hamilton Street, Hokitika"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -42.7191963,
#                     "lng": 170.9582255
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -42.7178824197085,
#                         "lng": 170.9596424302915
#                     },
#                     "southwest": {
#                         "lat": -42.7205803802915,
#                         "lng": 170.9569444697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "c6720f474a63ac4771d0e926b4244d0f0b315af9",
#             "name": "Great Views in Hokitika Sunset Point Apartment",
#             "photos": [
#                 {
#                     "height": 4128,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113584946212165874402\">Jack Mead</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAwZzdBOl-DSUWasbBZINy6XWKfJY9UB1o_6djKap6bEe7WyhGnS1iuL1FHER43gTy1vOcpMukWTJRQMy_ytiz4zaRsylU7ECWWYRKNZBjOdbC8lDyQttnETB2Jd8SWV5OEhAD9QevdPffTssqEfj8Y7DlGhSUnI350lOs8TVhMq2cGpgMzA7c3Q",
#                     "width": 2322
#                 }
#             ],
#             "place_id": "ChIJS53lahYvL20Roc4QxBCMrgk",
#             "plus_code": {
#                 "compound_code": "7XJ5+87 Hokitika, West Coast, New Zealand",
#                 "global_code": "4V9G7XJ5+87"
#             },
#             "rating": 4.6,
#             "reference": "ChIJS53lahYvL20Roc4QxBCMrgk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 8,
#             "vicinity": "5 Beach Street, Hokitika"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -42.7204873,
#                     "lng": 170.9650325
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -42.7191814197085,
#                         "lng": 170.9663438802915
#                     },
#                     "southwest": {
#                         "lat": -42.7218793802915,
#                         "lng": 170.9636459197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "3df2b25a9a5e2367f97e25438af834efe1f1bc54",
#             "name": "Pioneer Hotel",
#             "photos": [
#                 {
#                     "height": 3016,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112043984149513308405\">Pioneer Hotel</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAySyIqlgtDQ1fCmaJiYC3xW-KO8a0qx9qeDFsAsYDOg4Ssh-rv9BWOvGx9zNXe_RcCM2uGFlsZPvwNV_2Nzt-E1NceB2WzWTPRTodRlJFaXyzNDMXM96bE-akQZErz1OvEhCrrHZa0LG4sMdklMXUnIMUGhQ3qBbD5hq3OnhGvwYwiWZty1Vh1A",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJlw1zTRUvL20RbWfrYOwVoyg",
#             "plus_code": {
#                 "compound_code": "7XH8+R2 Hokitika, West Coast, New Zealand",
#                 "global_code": "4V9G7XH8+R2"
#             },
#             "rating": 4.3,
#             "reference": "ChIJlw1zTRUvL20RbWfrYOwVoyg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 104,
#             "vicinity": "80 Gibson Quay, Hokitika"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -42.71213699999999,
#                     "lng": 170.9694021
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -42.7108319197085,
#                         "lng": 170.9708347802915
#                     },
#                     "southwest": {
#                         "lat": -42.7135298802915,
#                         "lng": 170.9681368197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "20d016bb783fe208461325cb2eeab0c3ecd2829e",
#             "name": "Fantail Cottage",
#             "place_id": "ChIJoeG1820vL20R1leeGY6s704",
#             "plus_code": {
#                 "compound_code": "7XQ9+4Q Hokitika, West Coast, New Zealand",
#                 "global_code": "4V9G7XQ9+4Q"
#             },
#             "reference": "ChIJoeG1820vL20R1leeGY6s704",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "177 Sewell Street, Hokitika"
#         }
#     ],
#     "status": "OK"
# }
# first -42.7173686,170.9665427 Hotal is Beachfront Hotel Hokitika.
# ------------

# %%
 ideal_df.reset_index()
# Out:
#     index                 City Country  Temperature (F)  Humidity (%)  \
# 0      37                sabha      ly            50.74          24.0
# 1      95           georgetown      us            63.34         100.0
# 2     194          henties bay      na            65.32          83.0
# 3     220               laguna      br            64.42          82.0
# 4     265                  qom      ir            55.78          19.0
# 5     272                adeje      es            63.21          63.0
# 6     279  valverde del camino      es            55.00          58.0
# 7     301             luderitz      na            59.00          93.0
# 8     312                 jalu      ly            55.60          68.0
# 9     329                 chuy      uy            66.04          92.0
# 10    335                selma      us            57.02          54.0
# 11    346                aswan      eg            60.80          31.0
# 12    373             sterling      us            58.77          47.0
# 13    381             chipiona      es            55.72          54.0
# 14    394               lompoc      us            55.27          54.0
# 15    424                jumla      np            59.00          92.0
# 16    438           nouakchott      mr            69.80          16.0
# 17    500             socastee      us            54.57          87.0
# 18    501             hokitika      nz            63.70          71.0
#
#     Cloudiness (%)  Wind Speed (m/s)  Wind Speed (mph)        Lat         Lng  \
# 0              0.0              3.18          7.113469  27.036541   14.429024
# 1              1.0              5.82         13.018991  38.907609  -77.072258
# 2              0.0              2.01          4.496249 -22.113496   14.283204
# 3              0.0              2.26          5.055484 -28.487606  -48.839740
# 4              0.0              1.59          3.556735  34.641576   50.874603
# 5              0.0              3.36          7.516118  28.122060  -16.733821
# 6              1.0              1.99          4.451511  37.574634   -6.753414
# 7              0.0              6.93         15.501994 -26.642038   15.163908
# 8              0.0              4.07          9.104346  29.040621   21.499133
# 9              1.0              7.72         17.269177 -33.692754  -53.455282
# 10             1.0              6.93         15.501994  32.407359  -87.021101
# 11             0.0              6.93         15.501994  24.088938   32.899829
# 12             1.0              5.82         13.018991  38.220274  -98.207164
# 13             0.0              8.05         18.007367  36.734861   -6.431699
# 14             1.0              4.70         10.513618  34.639150 -120.457941
# 15             0.0              5.46         12.213692  29.278776   82.127840
# 16             0.0              5.82         13.018991  18.073530  -15.958237
# 17             1.0              5.82         13.018991  33.683504  -78.998368
# 18             0.0              3.29          7.359533 -42.717369  170.966543
#
#                                                  name  \
# 0                            محطة تاكسيات الشاطئ براك
# 1                  Kimpton Hotel Monaco Washington DC
# 2                              Fishermans Guest House
# 3                                   Pousada Barra Sul
# 4                             Qom International Hotel
# 5           Gran Tacande Wellness & Relax Costa Adeje
# 6             HOTEL MONTEAROMA (ulamde hotelera S.L.)
# 7                                 LÜDERITZ NEST HOTEL
# 8                                    Dr. Mohsen Villa
# 9                                   Nuevo Hotel Plaza
# 10                 Holiday Inn Express & Suites Selma
# 11                                          Nuba Nile
# 12                                  Country Inn Motel
# 13                                    Monterrey Costa
# 14                         Holiday Inn Express Lompoc
# 15                             Shah hotel & resturant
# 16                  Mauricenter Hotel فندق موري سانتر
# 17  Super 8 by Wyndham Myrtle Beach/Market Common ...
# 18                          Beachfront Hotel Hokitika
#
#                                           address
# 0                                محطة سبها، سبها،
# 1              700 F Street Northwest, Washington
# 2                                         Namibia
# 3                         State of Santa Catarina
# 4                                Qom, Eram Street
# 5          C/Alcalde Walter Paetzmann, s/n, Adeje
# 6        Plaza San Pedro, 1C, Valverde del Camino
# 7                       820 Dias Street, Luderitz
# 8                                            Jalu
# 9                   Avenida General Artigas, Chuy
# 10                        2000 Lincoln Way, Selma
# 11    9 Ahmed Ibn Al Abtal, El-Tahrir City, Aswan
# 12            430 South Broadway Avenue, Sterling
# 13            Paseo Costa de la Luz, 55, Chipiona
# 14                    1417 North H Street, Lompoc
# 15                                Karnali Highway
# 16                                     Mauritania
# 17  3450 US Highway 17 Bypass South, Myrtle Beach
# 18                    111 Revell Street, Hokitika

# %%
# Store 'Lat' and 'Lng' into  locations 
ideal_locations = ideal_df[["Lat", "Lng"]].astype(float)
ideal_humidity = ideal_df["Humidity (%)"].astype(float)
ideal_df.head()
hotel_df=ideal_df[["name","City","Country"]]
hotel_df['location'] =ideal_df['Lat'].map(str)+','+ideal_df['Lng'].map(str)
hotel_df.to_numpy()
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(ideal_locations, weights=ideal_humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 3)

fig.add_layer(heat_layer)

marker_locations=hotel_df["location"]
info_box_template = """
<dl>
<dt>Name</dt><dd>{hotel["name"]}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
hotel_info = [info_box_template.format(*hotel) for hotel in hotel_df]
markers = gmaps.marker_layer(marker_locations,info_box_content=hotel_info)
fig.add_layer(markers)

fig
# Out:
# /Users/jadetao/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-231-bf42f35380d2> in <module>
#      22 </dl>
#      23 """
# ---> 24 hotel_info = [info_box_template.format(*hotel) for hotel in hotel_df]
#      25 markers = gmaps.marker_layer(marker_locations,info_box_content=hotel_info)
#      26 fig.add_layer(markers)
#
# <ipython-input-231-bf42f35380d2> in <listcomp>(.0)
#      22 </dl>
#      23 """
# ---> 24 hotel_info = [info_box_template.format(*hotel) for hotel in hotel_df]
#      25 markers = gmaps.marker_layer(marker_locations,info_box_content=hotel_info)
#      26 fig.add_layer(markers)
#
# KeyError: 'hotel'

# %%
hotel_df
# Out:
#                                                   name                 City  \
# 37                            محطة تاكسيات الشاطئ براك                sabha
# 95                  Kimpton Hotel Monaco Washington DC           georgetown
# 194                             Fishermans Guest House          henties bay
# 220                                  Pousada Barra Sul               laguna
# 265                            Qom International Hotel                  qom
# 272          Gran Tacande Wellness & Relax Costa Adeje                adeje
# 279            HOTEL MONTEAROMA (ulamde hotelera S.L.)  valverde del camino
# 301                                LÜDERITZ NEST HOTEL             luderitz
# 312                                   Dr. Mohsen Villa                 jalu
# 329                                  Nuevo Hotel Plaza                 chuy
# 335                 Holiday Inn Express & Suites Selma                selma
# 346                                          Nuba Nile                aswan
# 373                                  Country Inn Motel             sterling
# 381                                    Monterrey Costa             chipiona
# 394                         Holiday Inn Express Lompoc               lompoc
# 424                             Shah hotel & resturant                jumla
# 438                  Mauricenter Hotel فندق موري سانتر           nouakchott
# 500  Super 8 by Wyndham Myrtle Beach/Market Common ...             socastee
# 501                          Beachfront Hotel Hokitika             hokitika
#
#     Country                       location
# 37       ly          27.0365406,14.4290236
# 95       us  38.9076089,-77.07225849999999
# 194      na         -22.1134964,14.2832038
# 220      br        -28.4876062,-48.8397403
# 265      ir          34.6415764,50.8746035
# 272      es         28.1220604,-16.7338211
# 279      es           37.5746343,-6.753414
# 301      na         -26.6420382,15.1639082
# 312      ly           29.040621,21.4991334
# 329      uy         -33.692754,-53.4552817
# 335      us  32.4073589,-87.02110069999999
# 346      eg           24.088938,32.8998293
# 373      us         38.2202739,-98.2071638
# 381      es  36.7348614,-6.431699000000001
# 394      us        34.6391501,-120.4579409
# 424      np   29.2787765,82.12783999999999
# 438      mr         18.0735299,-15.9582372
# 500      us          33.683504,-78.9983676
# 501      nz        -42.7173686,170.9665427
